# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
df = pd.read_csv('../../responses.csv')

# Filter to INCLUDE only non-engineering teams
teams_to_include = ['Customer Solutions', 'Customer Support', 'Pre-Sales']
df_filtered = df[df['Which team are you a part of?'].isin(teams_to_include)].copy()

# Get column names
team_col = 'Which team are you a part of?'
helpfulness_col = 'On a scale of 1 to 5, how would you rate the overall helpfulness of AI in your daily development tasks?'

# Create numeric mapping
rating_values = {
    'Extremely Helpful': 5,
    'Very Helpful': 4,
    'Moderately Helpful': 3,
    'Slightly Helpful': 2,
    'Not Helpful': 1
}

df_filtered['rating_numeric'] = df_filtered[helpfulness_col].map(rating_values)

# Define rating order
rating_order = ['Extremely Helpful', 'Very Helpful', 'Moderately Helpful', 'Slightly Helpful', 'Not Helpful']

# Create crosstab
team_sentiment = pd.crosstab(df_filtered[team_col], df_filtered[helpfulness_col])
team_sentiment = team_sentiment.reindex(columns=rating_order, fill_value=0)

# Calculate percentage for each team
team_sentiment_pct = team_sentiment.div(team_sentiment.sum(axis=1), axis=0) * 100

# Calculate average rating per team for sorting
team_avg_rating = df_filtered.groupby(team_col)['rating_numeric'].mean()

# Sort teams by average rating (best to worst)
sorted_teams = team_avg_rating.sort_values(ascending=True).index
team_sentiment_pct = team_sentiment_pct.reindex(sorted_teams)
team_sentiment = team_sentiment.reindex(sorted_teams)

# Get team sizes
team_sizes = team_sentiment.sum(axis=1)

# Create figure
fig, ax = plt.subplots(figsize=(14, 7))

# Modern purple-to-pink gradient for non-engineering teams
colors = ['#9C27B0', '#BA68C8', '#FBBF24', '#F97316', '#EF4444']

# Create stacked horizontal bar chart
left = np.zeros(len(sorted_teams))
bars = []

for i, rating in enumerate(rating_order):
    values = team_sentiment_pct[rating].values
    bars.append(ax.barh(range(len(sorted_teams)), values, left=left, 
                        color=colors[i], edgecolor='white', linewidth=2.5,
                        label=rating, height=0.75))
    
    # Add percentage labels if segment is large enough
    for j, (value, l) in enumerate(zip(values, left)):
        if value > 8:  # Only show label if segment is >8%
            ax.text(l + value/2, j, f'{value:.0f}%', 
                   ha='center', va='center', fontsize=12, weight='bold', color='white')
    
    left += values

# Customize plot
ax.set_yticks(range(len(sorted_teams)))

# Create y-axis labels with team name, average rating, and size
y_labels = []
for team in sorted_teams:
    avg = team_avg_rating[team]
    size = int(team_sizes[team])
    y_labels.append(f'{team}\n{avg:.2f}/5.0 (n={size})')

ax.set_yticklabels(y_labels, fontsize=12, weight='bold', color='#2C3E50')
ax.set_xlabel('Percentage of Team (%)', fontsize=14, weight='bold', color='#2C3E50', labelpad=10)
ax.set_title('Non-Engineering Teams: AI Helpfulness Sentiment Distribution', 
            fontsize=19, weight='bold', pad=25, color='#2C3E50')
ax.set_xlim(0, 100)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#E5E7EB')
ax.spines['bottom'].set_color('#E5E7EB')

# Add legend with improved styling
ax.legend(loc='upper right', fontsize=11, framealpha=0.95, 
         title='Helpfulness Rating', title_fontsize=12,
         edgecolor='#D1D5DB', fancybox=True, shadow=True)

# Add grid
ax.grid(axis='x', alpha=0.3, linestyle='--', zorder=0, color='#9CA3AF')

# Add overall average line reference with modern purple theme
overall_avg = df_filtered['rating_numeric'].mean()
ax.text(0.02, 0.98, f'Non-Eng Avg: {overall_avg:.2f}/5.0', 
        transform=ax.transAxes, ha='left', va='top',
        fontsize=12, weight='bold',
        bbox=dict(boxstyle='round,pad=0.7', facecolor='#F3E5F5', 
                 edgecolor='#9C27B0', linewidth=2, alpha=0.95),
        color='#6A1B9A')

# Add interpretation guide
guide_text = "← Lower satisfaction | Higher satisfaction →"
ax.text(0.5, -0.1, guide_text, 
        transform=ax.transAxes, ha='center',
        fontsize=11, style='italic', color='#6B7280',
        bbox=dict(boxstyle='round,pad=0.5', facecolor='#F3F4F6', 
                 edgecolor='#D1D5DB', linewidth=1.5, alpha=0.9))

plt.tight_layout()
plt.show()

# Print detailed summary
print("\n" + "="*80)
print("NON-ENGINEERING TEAMS - AI HELPFULNESS SENTIMENT ANALYSIS")
print("="*80)

print(f"\n📊 Non-Engineering Average: {overall_avg:.2f}/5.0")
print(f"   Total Team Members: {len(df_filtered)}")

# Compare to engineering
eng_teams_to_exclude = ['Customer Solutions', 'Customer Support', 'Pre-Sales']
df_eng = df[~df['Which team are you a part of?'].isin(eng_teams_to_exclude)].copy()
df_eng['rating_numeric'] = df_eng[helpfulness_col].map(rating_values)
eng_avg = df_eng['rating_numeric'].mean()

print(f"   Engineering Average: {eng_avg:.2f}/5.0")
print(f"   Difference: {abs(overall_avg - eng_avg):.2f} points")

print(f"\n⭐ Team Rankings (Best to Worst by Average Rating):")
print(f"{'Rank':<6} {'Team':<25} {'Avg Rating':<12} {'Size':<8} {'High Ratings %':<15}")
print("="*80)

for i, team in enumerate(sorted_teams[::-1], 1):  # Reverse to show best first
    avg = team_avg_rating[team]
    size = int(team_sizes[team])
    high_ratings = team_sentiment.loc[team, ['Extremely Helpful', 'Very Helpful']].sum()
    high_pct = (high_ratings / size * 100)
    
    print(f"{i:<6} {team:<25} {avg:<12.2f} {size:<8} {high_pct:<14.0f}%")

print(f"\n📈 Detailed Sentiment Breakdown:")
print(f"{'Team':<25} {'Extremely':<12} {'Very':<12} {'Moderately':<13} {'Slightly':<12} {'Not':<8}")
print("="*80)

for team in sorted_teams[::-1]:
    row = team_sentiment.loc[team]
    print(f"{team:<25} {int(row['Extremely Helpful']):<12} "
          f"{int(row['Very Helpful']):<12} "
          f"{int(row['Moderately Helpful']):<13} "
          f"{int(row['Slightly Helpful']):<12} "
          f"{int(row['Not Helpful']):<8}")

print(f"\n✨ Key Insights:")

# Best and worst teams
best_team = sorted_teams[-1]
worst_team = sorted_teams[0]
best_avg = team_avg_rating[best_team]
worst_avg = team_avg_rating[worst_team]

print(f"   🏆 Highest Satisfaction: {best_team} ({best_avg:.2f}/5.0)")
print(f"   📉 Lowest Satisfaction: {worst_team} ({worst_avg:.2f}/5.0)")
print(f"   📊 Spread: {best_avg - worst_avg:.2f} points")

# Consistency analysis
if best_avg - worst_avg < 0.5:
    print(f"\n   • Very consistent sentiment across all teams!")
elif best_avg - worst_avg < 1.0:
    print(f"\n   • Moderate variation between customer-facing teams")
else:
    print(f"\n   • Significant variation - {worst_team} may need different AI tools or training")

# Teams above/below average
above_avg_teams = [team for team in sorted_teams if team_avg_rating[team] > overall_avg]
below_avg_teams = [team for team in sorted_teams if team_avg_rating[team] < overall_avg]

print(f"\n   • {len(above_avg_teams)} teams above non-engineering average")
print(f"   • {len(below_avg_teams)} teams below non-engineering average")

# Unanimous positive sentiment check
for team in sorted_teams:
    negative_ratings = team_sentiment.loc[team, ['Slightly Helpful', 'Not Helpful']].sum()
    if negative_ratings == 0:
        print(f"\n   🎯 {team}: 100% positive ratings (Moderately or better)!")

# Compare to engineering sentiment
print(f"\n🔍 Non-Engineering vs Engineering Comparison:")
if overall_avg > eng_avg:
    print(f"   • Non-engineering teams rate AI HIGHER than engineering (+{overall_avg - eng_avg:.2f})")
    print(f"   • Customer-facing roles finding strong value in AI tools")
elif overall_avg < eng_avg:
    print(f"   • Engineering teams rate AI higher than non-engineering ({eng_avg - overall_avg:.2f} points)")
    print(f"   • Opportunity: Tailor AI tools/training for customer-facing workflows")
else:
    print(f"   • Both groups rate AI equally - strong company-wide adoption")

# Calculate overall high ratings for non-eng
high_ratings_total = team_sentiment[['Extremely Helpful', 'Very Helpful']].sum().sum()
high_ratings_pct = (high_ratings_total / len(df_filtered) * 100)
print(f"\n   • {high_ratings_pct:.0f}% of non-engineering rate AI as 'Very' or 'Extremely' Helpful")

print("\n" + "="*80 + "\n")
# Out:
# ================================================================================
# NON-ENGINEERING TEAMS - AI HELPFULNESS SENTIMENT ANALYSIS
# ================================================================================
#
# 📊 Non-Engineering Average: 4.00/5.0
#    Total Team Members: 14
#    Engineering Average: 3.55/5.0
#    Difference: 0.45 points
#
# ⭐ Team Rankings (Best to Worst by Average Rating):
# Rank   Team                      Avg Rating   Size     High Ratings %
# ================================================================================
# 1      Pre-Sales                 4.75         4        100           %
# 2      Customer Solutions        3.80         5        80            %
# 3      Customer Support          3.60         5        40            %
#
# 📈 Detailed Sentiment Breakdown:
# Team                      Extremely    Very         Moderately    Slightly     Not
# ================================================================================
# Pre-Sales                 3            1            0             0            0
# Customer Solutions        1            3            0             1            0
# Customer Support          1            1            3             0            0
#
# ✨ Key Insights:
#    🏆 Highest Satisfaction: Pre-Sales (4.75/5.0)
#    📉 Lowest Satisfaction: Customer Support (3.60/5.0)
#    📊 Spread: 1.15 points
#
#    • Significant variation - Customer Support may need different AI tools or training
#
#    • 1 teams above non-engineering average
#    • 2 teams below non-engineering average
#
#    🎯 Customer Support: 100% positive ratings (Moderately or better)!
#
#    🎯 Pre-Sales: 100% positive ratings (Moderately or better)!
#
# 🔍 Non-Engineering vs Engineering Comparison:
#    • Non-engineering teams rate AI HIGHER than engineering (+0.45)
#    • Customer-facing roles finding strong value in AI tools
#
#    • 71% of non-engineering rate AI as 'Very' or 'Extremely' Helpful
#
# ================================================================================
